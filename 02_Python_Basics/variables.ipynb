# %%
print("Variables")
# This is a comment
# Out:
# Variables

# %%
username = "seckin"
print(username)
# Out:
# seckin

# %%
# text is stored as strings (str)

double_quote_string = "This is a double quote string"
single_quote_string = 'This is a single quote string'

quote = "It's a beautiful world!" # ' can be used in "" strings; " can be used in '' strings

# a string across multiple lines
long_text = """
This is 
a long
long
text
across multiple
lines


"""

print(long_text)
# Out:
# This is
# a long
# long
# text
# across multiple
# lines

# %%
# integer
age = 35
print(age)

# float
average_score = 4.2
print(average_score)
# Out:
# 35
# 4.2

# %%
# boolean (True / False)
is_allowed_to_drive = True
is_blocked = False

print(is_allowed_to_drive)
print(is_blocked)
# Out:
# True
# False

# %%
type(average_score)
# Out:
# float

# %%
username = "seckin"
print(username)
username = "Masih" # we can re-assign values to variables
print(username)
username = 32.34 # values can be of a different data type
print(username)
username = "masih"
# Out:
# seckin
# Masih
# 32.34

# %%
len(long_text) # in-built function to get the length of something
# Out:
# 51

# %%
username = "leila"

username.capitalize()
# Out:
# 'Leila'

# %%
first_name = "Ali"
last_name = "hashemi"
print(first_name + " " + last_name.capitalize())

print(f"This is the full name: {first_name} {last_name.capitalize()}")


current_age = 25
print(f"{first_name} is {current_age + 2} years old.")
print(current_age)
# Out:
# Ali Hashemi
# This is the full name: Ali Hashemi
# Ali is 27 years old.
# 25

# %%
x = 10
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x // y)
print(x % y)

# both following lines are equal
# x = x * 2
x *= 2
x += 2
x -= 2
x /= 2
x //= 2
print(x)

print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 5.0
# True
# False
# True
# False

# %%
print("Tell me your username")
username = input()
print(f"You entered: {username}")
# Out:
# Tell me your username
# You entered: stephan

# %%
print("Enter your age")
age = int(input())
age += 1

# age++ # no increment operator in Python

print(f"You entered: {age}, but I added 1")
# Out:
# Enter your age
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 print("Enter your age")
# ----> 2 age = int(input())
#       3 age += 1
#       5 print(f"You entered: {age}, but I added 1")
#
# ValueError: invalid literal for int() with base 10: 'stephan'

# %%
name = "masih"
print(name)
upper_name = name.upper()
print(upper_name)
print(name)
# Out:
# masih
# MASIH
# masih
