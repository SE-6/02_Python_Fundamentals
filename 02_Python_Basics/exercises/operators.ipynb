# %%
print("Operators")
# Out:
# Operators

# %%
x = 4
y = 2
# 4²
print( 4 ** 2 )

print(x ** y)

print(x ** 0.5)
# Out:
# 16
# 16
# 2.0

# %%
(16 + 4)* 5
# Out:
# 100

# %%
# 100 - 30 + 14

20 + (4 ** 2)
# Out:
# 36

# %%
print(x > y)
print(x < y)
print(x == y)
# Out:
# True
# False
# False

# %%
name = "Max"

print(name == "Max") # is equal to
print(name != "Max") # is not equal to
# Out:
# True
# False

# %%
48 / 2

# %%
# 10
# 01010 # 10 in binary
# bitwise shift to right 
# 00101 # 5 in binary

10 >> 1 # binary shift by one to right is like floor division by 2
# Out:
# 5
