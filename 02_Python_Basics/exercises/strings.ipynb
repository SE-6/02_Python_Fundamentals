# %%
# This is a line comment

first_name = "Yusif" # This is the first name
last_name = "Rzaiev"

"""
This
comment
has multiple
lines
"""


bio = f"""
  My name is {first_name} {last_name}.
I am learning Python.
Programming is awesome!
Python!

"""



print(bio)
# Out:
#   My name is Yusif Rzaiev.
# I am learning Python.
# Programming is awesome!
# Python!

# %%
#             01
book_title = "Käpt'n Blaubär"
print(book_title[1])
print(book_title[-5])

print(book_title[7:])
print(book_title[7:11])
print(book_title[:6])
# Out:
# ä
# a
# Blaubär
# Blau
# Käpt'n

# %%
len(bio)
# Out:
# 72

# %%
print("Python" in bio)
# Out:
# True

# %%
print("Java" not in bio)
# Out:
# True

# %%
print(first_name.upper())
print(last_name.lower())
# Out:
# YUSIF
# rzaiev

# %%
print(bio)
print(bio.strip())
# print(bio)
# Out:
#   My name is Yusif Rzaiev.
# I am learning Python.
# Programming is awesome!
#
#
#
# My name is Yusif Rzaiev.
# I am learning Python.
# Programming is awesome!

# %%
input().strip()
# Out:
# '42'

# %%
print(bio.replace("Python", "coding"))
# Out:
#   My name is Yusif Rzaiev.
# I am learning coding.
# Programming is awesome!
# coding!

# %%
print(bio.strip().replace("\n", " ").split(" "))
# Out:
# ['My', 'name', 'is', 'Yusif', 'Rzaiev.', 'I', 'am', 'learning', 'Python.', 'Programming', 'is', 'awesome!', 'Python!']

# %%
# greeting = 'He said, "Python' + 's great!"'
greeting = "He said, \"Python's great!\""
print(greeting)

print("first Line\nsecond line\ttabbed")
# Out:
# He said, "Python's great!"
# first Line
# second line	tabbed
