# %%
name = "Jochen"
age = 32
height = 1.69

# %%
print(f"My name {name} and I am {age} and {height}cm tall.")
print("My name " + name +" and I am " + str(age) + " and " + str(height)+ "cm tall.")
# Out:
# My name Jochen and I am 32 and 1.69cm tall.
# My name Jochen and I am 32 and 1.69cm tall.

# %%
x, y = "hello", "world"

print(x, y)
# Out:
# hello world

# %%
name = "max"
age = 15
height = 1.80
print(f"My name {name} and I am {age} an {height} cm tall")
# Out:
# My name max and I am 15 an 1.8 cm tall

# %%
type(height)
# Out:
# float
