# %%
print("Tuples")
# Out:
# Tuples

# %%
my_list = []

my_tuple = (4, "a string", True)

print(my_tuple)
print(type(my_tuple))

location = (53.4, 13.4)
# Out:
# (4, 'a string', True)
# <class 'tuple'>

# %%
fruits1 = ("apple", "banana", "pineapple")
fruits2 = ("mango", "strawberry", "blueberry")

combine = fruits1 + fruits2
print(fruits1)
print(combine)
# Out:
# ('apple', 'banana', 'pineapple')
# ('apple', 'banana', 'pineapple', 'mango', 'strawberry', 'blueberry')

# %%
repeated = fruits1 * 2
print(repeated)
# Out:
# ('apple', 'banana', 'pineapple', 'apple', 'banana', 'pineapple')

# %%
"Hello, World " * 5
# Out:
# 'Hello, World Hello, World Hello, World Hello, World Hello, World '

# %%
location = (53.4, 13.4)
print(location[0])

# unpack
# (latitude, longitude) = location
latitude, longitude = location
print(latitude)
# Out:
# 53.4
# 53.4

# %%
favorite_colors = ("teal", "green", "red", "chartreuse")

first_color, second_color, _, _ = favorite_colors

first, *other_colors, last_one = favorite_colors

print(favorite_colors[-3])
print(second_color)
print(other_colors)
print(last_one)
# Out:
# green
# green
# ['green', 'red']
# chartreuse

# %%
f_color = favorite_colors[0]
s_color = favorite_colors[1]

# %%
my_list = [0, 1, 2, 3, 4, 5, 6]

zero, one, *_ = my_list

print(zero)
print(_)
# Out:
# 0
# [2, 3, 4, 5, 6]

# %%
users = [[1, "name"], [2, "max"], [3, "gesine"]]

transformed_list = [f"{username}:{id}" for (id, username) in users]
print(transformed_list)
# Out:
# ['name:1', 'max:2', 'gesine:3']
