# %% [markdown]
# Take the little list of names down there. They are new hires in your company, and we need to create corporate email addresses for them.
#
# 1. Check if "Samus Aran" is in the list already, if not, add her (via a list method)
# 2. Also check if "Ezio Auditore da Firenze" is in the list - same procedure here.
# 3. Sadly, "Geralt of Rivia" took another offer, remove him from the list, we might not see him in a while.
# 4. Finally, generate a new list (via list comprehension) with our corporate email:
#    e.g. "Guybrush Threepwood" -> "[guybrush.threepwood@wbscodingschool.dev](mailto:guybrush.threepwood@wbscodingschool.dev)"
#    - replace all spaces with `.`
#    - turn all letters to lowercase
#    - add "@wbscodingschool.dev"

# %%
new_hires = [
    "Guybrush Threepwood",
    "Lara Croft",
    "Gordon Freeman",
    "Geralt of Rivia",
    "Solid Snake",
    "Samus Aran",
    "Cloud Strife",
    "Master Chief",
    "Kratos",
    "Nathan Drake",
    "Arthur Morgan",
    "Jill Valentine",
    "Duke Nukem",
    "Max Payne",
    "Commander Shepard",
]

# %%
print("Samus Aran" in new_hires)
# Out:
# True

# %%
new_hires.append("Ezio Auditore da Firenze")

# %%
print("Ezio Auditore da Firenze" in new_hires)
# Out:
# True

# %%
if "Ezio Auditore da Firenze" not in new_hires:
    new_hires.append("Ezio Auditore da Firenze")

# %%
new_hires.remove("Geralt of Rivia")
print("Geralt of Rivia" in new_hires)
# Out:
# False

# %%
emails = [f"{name.lower().replace(" ", ".")}@wbscodingschool.dev" for name in new_hires]

print(emails)
# Out:
# ['guybrush.threepwood@wbscodingschool.dev', 'lara.croft@wbscodingschool.dev', 'gordon.freeman@wbscodingschool.dev', 'solid.snake@wbscodingschool.dev', 'samus.aran@wbscodingschool.dev', 'cloud.strife@wbscodingschool.dev', 'master.chief@wbscodingschool.dev', 'kratos@wbscodingschool.dev', 'nathan.drake@wbscodingschool.dev', 'arthur.morgan@wbscodingschool.dev', 'jill.valentine@wbscodingschool.dev', 'duke.nukem@wbscodingschool.dev', 'max.payne@wbscodingschool.dev', 'commander.shepard@wbscodingschool.dev', 'ezio.auditore.da.firenze@wbscodingschool.dev']
