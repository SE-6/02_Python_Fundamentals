# %% [markdown]
# Another bonus exercise! ❄️
# Here we have (somewhat realistic) temperature data from a late November in Berlin. It's CSV again. The fist line is the header, it just tells you what to expect in each column down the rows. Every line (row) represents a day. In between the commas (`,`) you find temperature measurements as floating point numbers (`3.7`). They start at the 0th hour. The very last column in each row is the date.
#
# Here are your tasks:
#
# - Convert the long string into a list. (We did this before, you can look it up) Ignore the header - slicing is your friend.
# - Save the first day (2025-11-17) in a variable on its own, so we can explore it further.
# - (first_day) Convert the data into a list of floats. Get rid of the date at the end.
# - (first_day) Find a way to get the minimum temperature and the maximum temperature. There are in-built functions for that in Python.
# - (first day) Let's say, the daylight day is always from 7:00 to 17:00. Calculate the average temperature of the daylight day.
#
# List Comprehensions. Try to get as far as you can without the aid of AI. It's ok, when you don't solve everything now. And remember, that you can do these in multiple steps.
#
# - Take the list of dates and create a new list, containing lists of temperatures, like: - `[[4.0, 3.7, 3.4, 3.2, 3.0, 2.9, 2.9, 3.4, 4.3, 5.4, 6.5, 7.5, 8.2, 8.7, 8.9, 8.4, 7.7, 6.8, 6.0, 5.4, 4.9, 4.5, 4.2, 3.9],  [
# 3.8, 3.5, 3.2, 3.0, 2.8, 2.7, 2.7, 3.2, 4.1, 5.2, 6.3, 7.3, 8.0, 8.5, 8.7, 8.2, 7.5, 6.6, 5.8, 5.2, 4.7, 4.3, 4.0, 3.7], ...]` - make sure to get rid of the dates and turn the numbers from strings into real floats
#   (This one is a harder, since it requires nested comprehensions.
#   You find examples here: https://www.geeksforgeeks.org/python/nested-list-comprehensions-in-python/)
#   (One solution is added here in a thread, so you can go on, if you're stuck.
#   )
#
# - take the list temperatures_floats and create two new lists from it, one containing only the maximum temperatures, one only the minimum temperatures
# - create a list based on temperatures*floats that containing the average temperature of each \_daylight day* (7-17h)
# - find the highest and lowest temperatures in total and the date they belong to
# - find the on average coldest _daylight day_

# %%
berlin_november = """0h,1h,2h,3h,4h,5h,6h,7h,8h,9h,10h,11h,12h,13h,14h,15h,16h,17h,18h,19h,20h,21h,22h,23h,date
4.0,3.7,3.4,3.2,3.0,2.9,2.9,3.4,4.3,5.4,6.5,7.5,8.2,8.7,8.9,8.4,7.7,6.8,6.0,5.4,4.9,4.5,4.2,3.9,2025-11-17
3.8,3.5,3.2,3.0,2.8,2.7,2.7,3.2,4.1,5.2,6.3,7.3,8.0,8.5,8.7,8.2,7.5,6.6,5.8,5.2,4.7,4.3,4.0,3.7,2025-11-18
3.5,3.2,2.9,2.7,2.5,2.4,2.4,2.9,3.8,4.9,6.0,7.0,7.7,8.2,8.4,7.9,7.2,6.3,5.5,4.9,4.4,4.0,3.7,3.4,2025-11-19
3.1,2.8,2.5,2.3,2.1,2.0,2.0,2.5,3.4,4.5,5.6,6.6,7.3,7.8,8.0,7.5,6.8,5.9,5.1,4.5,4.0,3.6,3.3,3.0,2025-11-20
2.8,2.5,2.2,2.0,1.8,1.7,1.7,2.2,3.1,4.2,5.3,6.3,7.0,7.5,7.7,7.2,6.5,5.6,4.8,4.2,3.7,3.3,3.0,2.7,2025-11-21
2.5,2.2,1.9,1.7,1.5,1.4,1.4,1.9,2.8,3.9,5.0,6.0,6.7,7.2,7.4,6.9,6.2,5.3,4.5,3.9,3.4,3.0,2.7,2.4,2025-11-22
# ...

# %%
# Save the first day (2025-11-17) in a variable on its own, so we can explore it further.
first_day = temp_days[0]
print(first_day)
# Out:
# 4.0,3.7,3.4,3.2,3.0,2.9,2.9,3.4,4.3,5.4,6.5,7.5,8.2,8.7,8.9,8.4,7.7,6.8,6.0,5.4,4.9,4.5,4.2,3.9,2025-11-17

# %%
# (first_day) Convert the data into a list of floats. Get rid of the date at the end.
first_day_values = first_day.split(",")[:-1]
# del first_day_values[-1]
print(max(first_day_values))
first_day_floats = [float(val) for val in first_day_values]
print(first_day_floats)
# Out:
# 8.9
# [4.0, 3.7, 3.4, 3.2, 3.0, 2.9, 2.9, 3.4, 4.3, 5.4, 6.5, 7.5, 8.2, 8.7, 8.9, 8.4, 7.7, 6.8, 6.0, 5.4, 4.9, 4.5, 4.2, 3.9]

# %%
# (first_day) Find a way to get the minimum temperature and the maximum temperature. There are in-built functions for that in Python.
print(min(first_day_floats))
print(max(first_day_floats))
# Out:
# 2.9
# 8.9

# %%
# (first day) Let's say, the daylight day is always from 7:00 to 17:00. Calculate the average temperature of the daylight day.
first_daylight_day = first_day_floats[7:18]
average = sum(first_daylight_day) / len(first_daylight_day)
print(round(average, 3))
# Out:
# 6.891

# %%
# Take the list of dates and create a new list, containing lists of temperatures
temp_days = [day.split(",")[:-1] for day in berlin_november.splitlines()][1:]
# print(temp_days)

temperature_floats = [
    [float(temp_in_str) for temp_in_str in temp] for temp in temp_days
]
print(temperature_floats)
# Out:
# [[4.0, 3.7, 3.4, 3.2, 3.0, 2.9, 2.9, 3.4, 4.3, 5.4, 6.5, 7.5, 8.2, 8.7, 8.9, 8.4, 7.7, 6.8, 6.0, 5.4, 4.9, 4.5, 4.2, 3.9], [3.8, 3.5, 3.2, 3.0, 2.8, 2.7, 2.7, 3.2, 4.1, 5.2, 6.3, 7.3, 8.0, 8.5, 8.7, 8.2, 7.5, 6.6, 5.8, 5.2, 4.7, 4.3, 4.0, 3.7], [3.5, 3.2, 2.9, 2.7, 2.5, 2.4, 2.4, 2.9, 3.8, 4.9, 6.0, 7.0, 7.7, 8.2, 8.4, 7.9, 7.2, 6.3, 5.5, 4.9, 4.4, 4.0, 3.7, 3.4], [3.1, 2.8, 2.5, 2.3, 2.1, 2.0, 2.0, 2.5, 3.4, 4.5, 5.6, 6.6, 7.3, 7.8, 8.0, 7.5, 6.8, 5.9, 5.1, 4.5, 4.0, 3.6, 3.3, 3.0], [2.8, 2.5, 2.2, 2.0, 1.8, 1.7, 1.7, 2.2, 3.1, 4.2, 5.3, 6.3, 7.0, 7.5, 7.7, 7.2, 6.5, 5.6, 4.8, 4.2, 3.7, 3.3, 3.0, 2.7], [2.5, 2.2, 1.9, 1.7, 1.5, 1.4, 1.4, 1.9, 2.8, 3.9, 5.0, 6.0, 6.7, 7.2, 7.4, 6.9, 6.2, 5.3, 4.5, 3.9, 3.4, 3.0, 2.7, 2.4], [2.2, 1.9, 1.6, 1.4, 1.2, 1.1, 1.1, 1.6, 2.5, 3.6, 4.7, 5.7, 6.4, 6.9, 7.1, 6.6, 5.9, 5.0, 4.2, 3.6, 3.1, 2.7, 2.4, 2.1], [1.9, 1.6, 1.3, 1.1, 0.9, 0.8, 0.8, 1.3, 2.2, 3.3, 4.4, 5.4, 6.1, 6.6, 6.8, 6.3, 5.6, 4.7, 3.9, 3.3, 2.8, 2.4, 2.1, 1.8], [1.5, 1.2, 0.9, 0.7, 
# ...

# %%
# take the list temperatures_floats and create two new lists from it, one containing only the maximum temperatures, one only the minimum temperatures
copy_first_day = temperature_floats[0]
sorted_first = sorted(copy_first_day)
# print(sorted_first)

maximums = [max(day) for day in temperature_floats]
minimums = [min(day) for day in temperature_floats]
print(maximums)
print(minimums)
# Out:
# [8.9, 8.7, 8.4, 8.0, 7.7, 7.4, 7.1, 6.8, 6.4, 5.9, 5.4, 4.7, 4.1, 3.7]
# [2.9, 2.7, 2.4, 2.0, 1.7, 1.4, 1.1, 0.8, 0.4, -0.1, -10.6, -1.3, -1.9, -2.3]

# %%
# create a list based on temperatures_floats that containing the average temperature of each daylight day (7-17h)
daylight_days = [day[7:18] for day in temperature_floats]
print(daylight_days)

averages = [round(sum(day) / len(day), 3) for day in daylight_days]
print(averages)
# Out:
# [[3.4, 4.3, 5.4, 6.5, 7.5, 8.2, 8.7, 8.9, 8.4, 7.7, 6.8], [3.2, 4.1, 5.2, 6.3, 7.3, 8.0, 8.5, 8.7, 8.2, 7.5, 6.6], [2.9, 3.8, 4.9, 6.0, 7.0, 7.7, 8.2, 8.4, 7.9, 7.2, 6.3], [2.5, 3.4, 4.5, 5.6, 6.6, 7.3, 7.8, 8.0, 7.5, 6.8, 5.9], [2.2, 3.1, 4.2, 5.3, 6.3, 7.0, 7.5, 7.7, 7.2, 6.5, 5.6], [1.9, 2.8, 3.9, 5.0, 6.0, 6.7, 7.2, 7.4, 6.9, 6.2, 5.3], [1.6, 2.5, 3.6, 4.7, 5.7, 6.4, 6.9, 7.1, 6.6, 5.9, 5.0], [1.3, 2.2, 3.3, 4.4, 5.4, 6.1, 6.6, 6.8, 6.3, 5.6, 4.7], [0.9, 1.8, 2.9, 4.0, 5.0, 5.7, 6.2, 6.4, 5.9, 5.2, 4.3], [0.4, 1.3, 2.4, 3.5, 4.5, 5.2, 5.7, 5.9, 5.4, 4.7, 3.8], [-0.1, 0.8, 1.9, 3.0, 4.0, 4.7, 5.2, 5.4, 4.9, 4.2, 3.3], [-0.8, 0.1, 1.2, 2.3, 3.3, 4.0, 4.5, 4.7, 4.2, 3.5, 2.6], [-1.4, -0.5, 0.6, 1.7, 2.7, 3.4, 3.9, 4.1, 3.6, 2.9, 2.0], [-1.8, -0.9, 0.2, 1.3, 2.3, 3.0, 3.5, 3.7, 3.2, 2.5, 1.6]]
# [6.891, 6.691, 6.391, 5.991, 5.691, 5.391, 5.091, 4.791, 4.391, 3.891, 3.391, 2.691, 2.091, 1.691]

# %%
# find the highest and lowest temperatures in total and the date they belong to
# print( (max(maximums)))
dates = [day.split(",")[-1] for day in berlin_november.splitlines()][1:]
max_temp = max(maximums)
date_index = maximums.index(max_temp)
print("Warmest", dates[date_index])

min_temp = min(minimums)
date_index_cold = minimums.index(min_temp)
print("Coldest", dates[date_index_cold])
# Out:
# Warmest 2025-11-17
# Coldest 2025-11-27

# %%
# find the on average coldest _daylight day_
coldest_avg = min(averages)
print(dates[averages.index(coldest_avg)])
# Out:
# 2025-11-30
