# %%
# Our library system is online again. And we took the liberty to update a few parts.
# Now our program stores users in Python Dictionaries and all users in a comfortable list.

# Task 1
# Add at least one more user from the old exercise here.
# You can manually add the new dictionary to the list.
# Include a "lang" field.

library_users = [
    {
        "id": 123,
        "name": "Guybrush Threepwood",
        "email": "mighty@pirate.gov",
        "borrowed_books": 1,
        "return_date": "1990-10-15",
        "lang": "es",
    },
    {
        "id": 666,
        "name": "Gandalf the Grey",
        "email": "pass@shall.not",
        "borrowed_books": 100,
        "return_date": "2026-01-31",
        "lang": "de",
    },
    {
        "id": 255,
        "name": "Hermione Granger",
        "email": "leviosa@hogwarts.ac.uk",
        "borrowed_books": 42,
        "return_date": "2026-01-15",
        "lang": "en",
    },
    {
        "id": 65,
        "name": "Frodo Baggins",
        "email": "ringbearer@shire.me",
        "borrowed_books": 2,
        "return_date": "3019-03-25",
        "lang": "en",
    },
]

# %%
# Task 2
# We want to send out internationalized emails to our users to inform them about our status.
# Finish this dictionary Dictionary according to the examples down below. Each piece of the email needs a label, that acts as a key in this dictionary, where we can find an English, a Spanish and a German variant.


# finish this

# Examples
email_example_en = """Dear Guybrush Threepwood,
we wish to inform you, that our library system is working flawlessly again.
Please confirm, that this is your current eMail address: mighty@pirate.gov.
You currently borrowed 1 book(s) that need to be returned by 15.10.1990.
Than you so much and Happy New Year,
Your Library Team"""

email_example_de = """Lieber Guybrush Threepwood,
wir möchten Sie darüber informieren, dass unser Bibliothekssystem wieder einwandfrei funktioniert.
Bitte bestätigen Sie, dass dies Ihre aktuelle E-Mail-Adresse ist: mighty@pirate.gov.
Sie haben derzeit 1 Buch ausgeliehen, das zurückgegeben werden muss bis zum 15.10.1990.
Vielen Dank und ein frohes neues Jahr,
Ihr Bibliotheksteam"""

email_example_es = """Estimad@s Guybrush Threepwood:
Le informamos de que nuestro sistema bibliotecario vuelve a funcionar correctamente.
Confirme que esta es su dirección de correo electrónico actual: mighty@pirate.gov.
Actualmente tiene 1 libro prestado que debe devolver antes del 15/10/1990.
Muchas gracias y feliz año nuevo.
El equipo de la biblioteca."""

email_pieces = {
    "greeting": {"en": "Dear", "de": "Lieber", "es": "Estimad@s"},
    "info": {
        "en": "we wish to inform you, that our library system is working flawlessly again",
        "de": "wir möchten Sie darüber informieren, dass unser Bibliothekssystem wieder einwandfrei funktioniert",
        "es": "Le informamos de que nuestro sistema bibliotecario vuelve a funcionar correctamente",
    },
    "email_confirmation": {
        "en": "Please confirm, that this is your current eMail address:",
        "de": "Bitte bestätigen Sie, dass dies Ihre aktuelle E-Mail-Adresse ist:",
        "es": "Confirme que esta es su dirección de correo electrónico actual:",
    },
    "borrow_status_one": {
        "en": "You currently borrowed",
        "de": "Sie haben derzeit",
        "es": "Actualmente tiene",
    },
    "borrow_status_two": {
        "en": "book(s) that need to be returned by",
        "de": "Buch ausgeliehen, das zurückgegeben werden muss bis zum",
        "es": "libro prestado que debe devolver antes del",
    },
    "outro": {
        "en": """Than you so much and Happy New Year,
Your Library Team""",
        "de": """Vielen Dank und ein frohes neues Jahr,
Ihr Bibliotheksteam""",
        "es": """Muchas gracias y feliz año nuevo.
El equipo de la biblioteca.""",
    },
}

# %%
# Task 3
# Create an email string based off of the first user in the list. Piece their email together with the help of their user information and our email_pieces!
first_user = library_users[2]
lang = first_user["lang"]
email = f"""{email_pieces["greeting"][lang]} {first_user["name"]},
{email_pieces["info"][lang]}: {first_user["email"]}.
{email_pieces["borrow_status_one"][lang]} {first_user["borrowed_books"]} {email_pieces["borrow_status_two"][lang]} {first_user["return_date"]}.
{email_pieces["outro"][lang]}"""

print(email)
# Out:
# Dear Hermione Granger,
# we wish to inform you, that our library system is working flawlessly again: leviosa@hogwarts.ac.uk.
# You currently borrowed 42 book(s) that need to be returned by 2026-01-15.
# Than you so much and Happy New Year,
# Your Library Team

# %%
# Bonus Bonus
# Create a list of emails via list comprehension!
emails = [
    f"""{email_pieces["greeting"][user["lang"]]} {user["name"]},
{email_pieces["info"][user["lang"]]}: {user["email"]}.
{email_pieces["borrow_status_one"][lang]} {user["borrowed_books"]} {email_pieces["borrow_status_two"][user["lang"]]} {user["return_date"]}.
{email_pieces["outro"][user["lang"]]}"""
    for user in library_users
]

print(emails)
# Out:
# ['Estimad@s Guybrush Threepwood,\nLe informamos de que nuestro sistema bibliotecario vuelve a funcionar correctamente: mighty@pirate.gov.\nYou currently borrowed 1 libro prestado que debe devolver antes del 1990-10-15.\nMuchas gracias y feliz año nuevo.\nEl equipo de la biblioteca.', 'Lieber Gandalf the Grey,\nwir möchten Sie darüber informieren, dass unser Bibliothekssystem wieder einwandfrei funktioniert: pass@shall.not.\nYou currently borrowed 100 Buch ausgeliehen, das zurückgegeben werden muss bis zum 2026-01-31.\nVielen Dank und ein frohes neues Jahr,\nIhr Bibliotheksteam', 'Dear Hermione Granger,\nwe wish to inform you, that our library system is working flawlessly again: leviosa@hogwarts.ac.uk.\nYou currently borrowed 42 book(s) that need to be returned by 2026-01-15.\nThan you so much and Happy New Year,\nYour Library Team', 'Dear Frodo Baggins,\nwe wish to inform you, that our library system is working flawlessly again: ringbearer@shire.me.\nYou currently borrowed 2 book(s) that need to be returned by 3019-03-25.\nThan you so much and Happy New Year,\nYour Library Team']
