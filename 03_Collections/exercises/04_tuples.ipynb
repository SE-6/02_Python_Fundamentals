# %%
print("Tuples Exercise")
# Out:
# Tuples Exercise

# %%
my_tuple = ("42",)

print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
get_presents_for = ("Miriam", "Jeremiah", "Isaiah", "Marietta", "Grandma")

print(get_presents_for)
# Out:
# ('Miriam', 'Jeremiah', 'Isaiah', 'Marietta', 'Grandma')

# %%
*kids, adult1, adult2 = get_presents_for
print(kids)
# Out:
# ['Miriam', 'Jeremiah', 'Isaiah']

# %%
print(get_presents_for[-1])
print(get_presents_for[1::2])
print(get_presents_for[4:0:-1])
# Out:
# Grandma
# ('Jeremiah', 'Marietta')
# ('Grandma', 'Marietta', 'Isaiah', 'Jeremiah')

# %%
"Grandma" in get_presents_for
# Out:
# True

# %%
get_presents_for.count("Grandma")
# Out:
# 2

# %%
get_presents_for.index("Grandma")
# Out:
# 1

# %%
more_people = ("Sebastian", "Paul", "Hannah")
all_people = get_presents_for + more_people
print(get_presents_for)
print(all_people)
# Out:
# ('Miriam', 'Jeremiah', 'Isaiah', 'Marietta', 'Grandma')
# ('Miriam', 'Jeremiah', 'Isaiah', 'Marietta', 'Grandma', 'Sebastian', 'Paul', 'Hannah')

# %%
various_things = ([1, 2, 3, 4], [2, 3, 4, 5])
various_things[0].append("new thingy")
print(various_things)

list1, list2 = various_things

list1[0] = "CHANGED!"

print(list1)
print(various_things)

print(type(various_things))
print(type(list1))
print(type(list2))

various_things = ((1, 2, 3, 4), (2, 3, 4, 5))
# Out:
# ([1, 2, 3, 4, 'new thingy'], [2, 3, 4, 5])
# ['CHANGED!', 2, 3, 4, 'new thingy']
# (['CHANGED!', 2, 3, 4, 'new thingy'], [2, 3, 4, 5])
# <class 'tuple'>
# <class 'list'>
# <class 'list'>

# %%
DO_NOT_CHANGE_THIS = 42

# const a_real_constant = 34
