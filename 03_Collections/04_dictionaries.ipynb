# %%
print("Dictionaries!")
# Out:
# Dictionaries!

# %%
a_tuple = (12, 43)
something = {12, 34, 45, 12}
print(something)

english_to_german = {
    "morning": "Morgen",
    "noon": "Mittag",
    "evening": "Abend",
}

print(english_to_german["noon"])
print(english_to_german.get("night", "I don't know"))
# Out:
# {34, 12, 45}
# Mittag
# I don't know

# %%
my_homepage = {"hero_text": "Welcome to my Website!"}

# %%
my_dictionary = {"strings": "Hello, World", 123: 987, (3, 6): "Nice tuple", 3.14: "PI"}


# all_keys = [k for k in my_dictionary.keys()]
# print(type(all_keys[-1]))

# %%
my_fruits = ["apple", "kiwi", "orange"]
my_fruits[0] = "pineapple"
print(my_fruits)
# Out:
# ['pineapple', 'kiwi', 'orange']

# %%
my_dictionary["strings"] = "Hello, Mars"
my_dictionary["new value"] = "now, it's here"
print(my_dictionary)
# Out:
# {'strings': 'Hello, Mars', 123: 987, (3, 6): 'Nice tuple', 3.14: 'PI', 'new value': "now, it's here"}

# %%
tweets = [
    {
        "author": "ThePrimeagen",
        "tweet": "This is my latest stuff...",
        "timestamp": 178736434534,
    },
    {
        "author": "Wes Bos",
        "tweet": "This is my latest stuff...",
        "timestamp": 178736434534,
    },
    {
        "author": "Guido van Rossum",
        "tweet": "This is my latest stuff...",
        "timestamp": 178736434534,
    },
    {
        "author": "Geralt",
        "tweet": "This is my latest stuff...",
        "timestamp": 178736434234,
    },
]

# %%
my_desk = [1, ("stuff", 42), [tweets, 65], {1: 6, 4: 2}]

print("stuff" in my_desk)
print(("stuff", 42) in my_desk)
# Out:
# False
# True

# %%
copy_of_en_to_de = english_to_german.copy()

english_to_german["morning"] = "Morgengrauen"

print(english_to_german)
print(copy_of_en_to_de)
# Out:
# {'morning': 'Morgengrauen', 'noon': 'Mittag', 'evening': 'Abend'}
# {'morning': 'Morgen', 'noon': 'Mittag', 'evening': 'Abend'}

# %%
morning = english_to_german.pop("morning")
print(english_to_german)
print(morning)
# Out:
# {'noon': 'Mittag', 'evening': 'Abend'}
# Morgengrauen

# %%
last_inserted = english_to_german.popitem()
print(english_to_german)
print(last_inserted)
# Out:
# {'noon': 'Mittag'}
# ('evening', 'Abend')

# %%
del english_to_german["noon"]
english_to_german.clear()
print(english_to_german)
# Out:
# {}
