# %%
print("Fun exercises!")
# Out:
# Fun exercises!

# %%
# Sum of List Elements
# Create a function sum_list(numbers) that takes a list of numbers and returns their sum.
# Use a loop to iterate through the list.
# Use a variable to accumulate the total and return it.

nums = [4, 2, 7, 3, 9, 2]
another_list = [123, 45, 234, 676, 432]


def sum_list(nums):
    total = 0
    for num in nums:
        total += num
    return total


sum1 = sum_list(nums)
sum2 = sum_list(another_list)

print(sum1)
print(sum2)
sum_list(nums)
# Out:
# 27
# 1510
# 27

# %%
nums = [1, 2, 3, 4, 5]


def sum_list(*args, **kwargs):
    for arg in args:
        print(arg)

    for key, val in kwargs.items():
        print(key, val)


print(sum_list(1, 2, 3, 4, hello="again", color="green"))
# Out:
# 1
# 2
# 3
# 4
# hello again
# color green
# None

# %%
# Repeated Greeting
# Write a function repeat_greeting(name, times) that prints a greeting to name a specified number of times.
# Use a loop to print the greeting repeatedly.
# Each greeting should be printed on a new line.


def repeat_greeting(name: str, times: int) -> None:
    """Prints a name multiple times"""
    # print(f"Hello, {name}!\n" * times)
    for _ in range(times):
        print(f"Hello, {name}!")


repeat_greeting("Masih", 5)
# Out:
# Hello, Masih!
# Hello, Masih!
# Hello, Masih!
# Hello, Masih!
# Hello, Masih!

# %%
def repeat_greeting(name, times=2):
    """Prints a name multiple times"""
    # print(f"Hello, {name}!\n" * times)
    for _ in range(times):
        print(f"Hello, {name}!")


repeat_greeting("Masih", 5)
repeat_greeting(times=3, name="Yusif")
repeat_greeting("Leila")
repeat_greeting("Seckin")
# Out:
# Hello, Masih!
# Hello, Masih!
# Hello, Masih!
# Hello, Masih!
# Hello, Masih!
# Hello, Yusif!
# Hello, Yusif!
# Hello, Yusif!
# Hello, Leila!
# Hello, Leila!
# Hello, Seckin!
# Hello, Seckin!

# %%
# Factorial Calculation
# Define a function factorial(n) that returns the factorial of a given number n.
# Use a loop (such as a for or while loop) to multiply numbers from 1 to n.
# Return the factorial result.

# 5! -> 1 * 2 * 3 * 4 * 5


def factorial(n):
    # if n > 50:
    #     # print("That's too big")
    #     # return
    #     raise ValueError("This number is too large")
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result


res = factorial(100)
print(res)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
1 * 2 * 3 * 4 * 5
# Out:
# 120

# %%
# Fibonacci Sequence Generator
# Create a function fibonacci(n) that returns a list containing the first n numbers of the Fibonacci sequence.
# Use loops and conditionals to calculate each Fibonacci number.
# Start the sequence with 0 and 1, then build the sequence up to n terms.

# >>> fibonacci(6)
# [0, 1, 1, 2, 3, 5]


def fibonacci(num):
    a = [0, 1]
    for _ in range(2, num):
        new_number = a[-2] + a[-1]
        a.append(new_number)
    return a[:num]


seq = fibonacci(-2)
print(seq)
# Out:
# []

# %%
# Write a function max_of_two(a, b) that returns the larger of two numbers.
# Use an if...else conditional to compare a and b.
# Return the greater value.

# >>> max_of_two(12, 65)
# 65

# def max_of_two(a, b):
#   if a > b:
#     return a
#   else:
#     return b


# def max_of_two(a, b):
#   if a > b:
#     return a
#   return b


def max_of_two(a, b):
    return a if a > b else b


maxL = lambda a, b: a if a > b else b

print(max_of_two(12, 65))
print(maxL(345, 12))
# Out:
# 65
# 345

# %%
# Print a Pattern with Nested Loops
# Design a function print_triangle(rows) that prints a right-angled triangle of asterisks (*) with a given number of rows.
# Use nested loops: an outer loop for rows and an inner loop for printing asterisks in each row.
# Each subsequent row should have one more asterisk than the previous row.

# >>> print_triangle(3)
# *
# **
# ***


def print_triangle(rows):
    for i in range(1, rows + 1):
        for _ in range(i):
            print("*", end="")
        print("")


print_triangle(3)
# Out:
# *
# **
# ***
